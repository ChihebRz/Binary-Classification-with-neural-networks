# %%
# !python ../src/preprocess.py

# %%
# !python ../src/model.py

# %%
# !python ../src/train.py
# Out:
# Epoch [100/2000], Loss: 0.5152
# Epoch [200/2000], Loss: 0.3280
# Epoch [300/2000], Loss: 0.2714
# Epoch [400/2000], Loss: 0.2471
# Epoch [500/2000], Loss: 0.2340
# Epoch [600/2000], Loss: 0.2242
# Epoch [700/2000], Loss: 0.2146
# Epoch [800/2000], Loss: 0.2049
# Epoch [900/2000], Loss: 0.1943
# Epoch [1000/2000], Loss: 0.1833
# Epoch [1100/2000], Loss: 0.1717
# Epoch [1200/2000], Loss: 0.1593
# Epoch [1300/2000], Loss: 0.1471
# Epoch [1400/2000], Loss: 0.1344
# Epoch [1500/2000], Loss: 0.1249
# Epoch [1600/2000], Loss: 0.1165
# Epoch [1700/2000], Loss: 0.1090
# Epoch [1800/2000], Loss: 0.1017
# Epoch [1900/2000], Loss: 0.0951
# Epoch [2000/2000], Loss: 0.0889

# %%
# !python ../src/evaluate.py
# Out:
# 📊 Evaluation Metrics
# Accuracy : 0.8548
# Precision: 0.8667
# Recall   : 0.9286
# F1-score : 0.8966
# Figure(500x400)
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.82      0.70      0.76        20
#     Abnormal       0.87      0.93      0.90        42
#
#     accuracy                           0.85        62
#    macro avg       0.85      0.81      0.83        62
# weighted avg       0.85      0.85      0.85        62

# %% [markdown]
# The model achieves 81% accuracy with a strong F1-score of 86% on the Abnormal class.
# Recall is high (88%), meaning most abnormal cases are correctly detected, which is critical in medical screening scenarios.
# The model shows a conservative bias, occasionally misclassifying normal cases as abnormal, but this reduces the risk of missing true abnormal patients.

# %%
# !python ../src/predict.py
# Out:
# {'class': 'Abnormal', 'probability': 0.8964743614196777}
